# %% [markdown]
# ### In this notebook I've compaired 5 SOTA model Bangla summarization ROUGE test result. The result dataset is avilable [here](https://kaggle.com/datasets/5d06d02e6778b7d73c2dd67b30db407e4247ba80e69f9d96f974ea94b05064eb).

# %% [markdown]
# ### From this comparison, we can see that the Gemma 2 9B model performs well among the other models. The LLaMA 3.1 and FILM are also close competitors to the Gemma 2. The LLaMA 3 8B model performs worse than the Gemma 2B model.

# %% [markdown]
# To see all the comparisons, please scroll down to the end.

# %%
import pandas as pd

# %%
film_rouge1 = pd.read_csv('/kaggle/input/ROUGE_test_result/FILM_rouge1_results.csv')
film_rougeL = pd.read_csv('/kaggle/input/ROUGE_test_result/FILM_rougeL_results.csv')
la31_rouge1 = pd.read_csv('/kaggle/input/ROUGE_test_result/L31_rouge1_results.csv')
la31_rougeL = pd.read_csv('/kaggle/input/ROUGE_test_result/L31_rougeL_results.csv')
g2b_rouge1 = pd.read_csv('/kaggle/input/ROUGE_test_result/g2b_rouge1_results.csv')
g2b_rougeL = pd.read_csv('/kaggle/input/ROUGE_test_result/g2b_rougeL_results.csv')
la3_rouge1 = pd.read_csv('/kaggle/input/ROUGE_test_result/la3_rouge1_results.csv')
la3_rougeL = pd.read_csv('/kaggle/input/ROUGE_test_result/la3_rougeL_results.csv')
gm29_rouge1 = pd.read_csv('/kaggle/input/ROUGE_test_result/gm29_rouge1_results.csv')
gm29_rougeL = pd.read_csv('/kaggle/input/ROUGE_test_result/gm29_rougeL_results.csv')

# %%
import pandas as pd

dataframes = [film_rouge1, la31_rouge1, g2b_rouge1, la3_rouge1, gm29_rouge1]

combined_df = pd.concat(dataframes, axis=0, ignore_index=True)

# %%
film_rougeL, la31_rougeL, g2b_rougeL, la3_rougeL, gm29_rougeL

# %%
combined_dfL = pd.concat([film_rougeL, la31_rougeL, g2b_rougeL, la3_rougeL, gm29_rougeL], ignore_index=True)

# %%
avg_metricsL = combined_dfL.groupby('Model').agg({
    'R-L Precision': 'mean',
    'R-L Recall': 'mean',
    'R-L F1': 'mean'
}).reset_index()

# Display the average scores
print(avg_metricsL)
# Out:
#           Model  R-L Precision  R-L Recall    R-L F1
# 0      Gemma 2b       0.475575    0.387345  0.393385
# 1     Gemma2 9b       0.512990    0.430421  0.451765
# 2       Llama 3       0.409070    0.445607  0.390156
# 3     Llama 3.1       0.488226    0.431421  0.433025
# 4  Mistral FILM       0.505167    0.412302  0.432554

# %%
avg_metricsL = combined_df.groupby('Model').agg({
    'R1 Precision': 'mean',
    'R1 Recall': 'mean',
    'R1 F1': 'mean'
}).reset_index()

# Display the average scores
print(avg_metricsL)
# Out:
#           Model  R1 Precision  R1 Recall     R1 F1
# 0      Gemma 2b      0.153978   0.120111  0.123750
# 1     Gemma2 9b      0.221329   0.176950  0.189677
# 2       Llama 3      0.124687   0.135009  0.118648
# 3     Llama 3.1      0.187373   0.161199  0.164028
# 4  Mistral FILM      0.194095   0.147957  0.159568

# %%
import plotly.express as px

fig = px.line(
    combined_df, 
    x='Context size', 
    y='R1 Precision', 
    color='Model',  
    markers=True,   
    title='R1 Precision vs Context size for each Model'
)

fig.update_layout(
    xaxis_title='Context size',
    yaxis_title='R1 Precision',
    legend_title='Model'
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="32cefb61-a4df-422d-a751-58f80adcd234" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32cefb61-a4df-422d-a751-58f80adcd234")) {                    Plotly.newPlot(                        "32cefb61-a4df-422d-a751-58f80adcd234",                        [{"hovertemplate":"Model=Mistral FILM\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 Precision=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mistral FILM","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mistral FILM","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.177108308,0.220964868,0.255622711,0.135876501,0.269185,0.19214534,0.184283088,0.143540362,0.21693111,0.145290809],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3.1\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 Precision=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3.1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3.1","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.144210789,0.192904589,0.2688846,0.168953178,0.24107035,0.194215347,0.209419136,0.128311688,0.186729178,0.139028782],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma 2b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 Precision=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma 2b","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma 2b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.134961274,0.148068541,0.245974442,0.12272578,0.195168067,0.135254568,0.100331014,0.155470641,0.162160738,0.139660895],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 Precision=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.123977315,0.224836367,0.162410714,0.129937403,0.164613305,0.132937763,0.066498321,0.08756705,0.09009565,0.063994716],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma2 9b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 Precision=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma2 9b","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma2 9b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.30975904,0.227678565,0.319571032,0.223511097,0.185874383,0.20427306,0.262793514,0.112117605,0.166402791,0.201309769],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type": ...

# %%
import plotly.express as px

fig = px.line(
    combined_df, 
    x='Context size', 
    y='R1 Recall', 
    color='Model',  
    markers=True,   
    title='R1 Recall vs Context size for each Model'
)

fig.update_layout(
    xaxis_title='Context size',
    yaxis_title='R1 Recall',
    legend_title='Model'
)

fig.show()
# Out:
# <div>                            <div id="817a5a65-818b-49da-b579-7fe5b2810254" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("817a5a65-818b-49da-b579-7fe5b2810254")) {                    Plotly.newPlot(                        "817a5a65-818b-49da-b579-7fe5b2810254",                        [{"hovertemplate":"Model=Mistral FILM\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 Recall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mistral FILM","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mistral FILM","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.150703601,0.150664205,0.162778535,0.165630596,0.19520651,0.112212933,0.143525818,0.111884377,0.177750572,0.109217623],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3.1\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 Recall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3.1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3.1","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.125965458,0.200801609,0.203127233,0.168139948,0.220728003,0.139920164,0.173613191,0.08441667,0.166432329,0.128847891],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma 2b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 Recall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma 2b","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma 2b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.170149737,0.102964519,0.153959047,0.132150219,0.12166896,0.099449401,0.08801032,0.129102422,0.125619468,0.078031394],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 Recall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.152010702,0.179280727,0.145458661,0.120043274,0.203600707,0.142075399,0.111912769,0.076791668,0.154788514,0.06412611],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma2 9b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 Recall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma2 9b","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma2 9b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.225597658,0.200677468,0.258858253,0.203980402,0.170581158,0.161819478,0.191632214,0.069829268,0.151753324,0.134767156],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"chorop ...

# %%
import plotly.express as px


fig = px.line(
    combined_df, 
    x='Context size', 
    y='R1 F1', 
    color='Model',  
    markers=True,   
    title='R1 F1 vs Context size for each Model'
)

# Customize axis labels
fig.update_layout(
    xaxis_title='Context size',
    yaxis_title='R1 F1',
    legend_title='Model'
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="af3de073-6f08-4af4-aed2-09ceee906fcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af3de073-6f08-4af4-aed2-09ceee906fcd")) {                    Plotly.newPlot(                        "af3de073-6f08-4af4-aed2-09ceee906fcd",                        [{"hovertemplate":"Model=Mistral FILM\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 F1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mistral FILM","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mistral FILM","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.15582532,0.172128388,0.196241268,0.141825261,0.22255923,0.135361159,0.149438566,0.117413764,0.186242684,0.118648502],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3.1\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 F1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3.1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3.1","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.132281799,0.185943409,0.220952545,0.158474386,0.224104313,0.154113392,0.183426855,0.09651538,0.159610296,0.124859762],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma 2b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 F1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma 2b","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma 2b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.140639437,0.117403994,0.183731715,0.117213686,0.144219292,0.104150441,0.088600266,0.120925836,0.123180909,0.097434914],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 F1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.128738504,0.180557182,0.138865111,0.102441687,0.175281689,0.132135848,0.082825987,0.075244547,0.112817388,0.057571387],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma2 9b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR1 F1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma2 9b","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma2 9b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.255917531,0.200458418,0.276386024,0.208324061,0.174008324,0.177673489,0.212943701,0.085228273,0.148352771,0.157478775],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{ ...

# %%
import pandas as pd
import plotly.graph_objects as go



combined_df['R1 Precision'] = pd.to_numeric(combined_df['R1 Precision'], errors='coerce')
combined_df['R1 Recall'] = pd.to_numeric(combined_df['R1 Recall'], errors='coerce')
combined_df['R1 F1'] = pd.to_numeric(combined_df['R1 F1'], errors='coerce')

avg_metrics = combined_df.groupby('Model').agg({
    'R1 Precision': 'mean',
    'R1 Recall': 'mean',
    'R1 F1': 'mean'
}).reset_index()

fig = go.Figure()

fig.add_trace(go.Bar(
    x=avg_metrics['Model'],
    y=avg_metrics['R1 Precision'],
    name='R1 Precision',
    marker_color='blue'
))

fig.add_trace(go.Bar(
    x=avg_metrics['Model'],
    y=avg_metrics['R1 Recall'],
    name='R1 Recall',
    marker_color='green'
))

fig.add_trace(go.Bar(
    x=avg_metrics['Model'],
    y=avg_metrics['R1 F1'],
    name='R1 F1',
    marker_color='red'
))

fig.update_layout(
    title='Comparison of Average R1 Metrics for Each Model',
    xaxis_title='Model',
    yaxis_title='Average Score',
    barmode='group',  
    legend_title='Metrics',
    plot_bgcolor='rgba(0,0,0,0)',  
    xaxis=dict(tickangle=-45)  
)

fig.show()
# Out:
# <div>                            <div id="4c010246-2609-498b-91e9-3c8666add7d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c010246-2609-498b-91e9-3c8666add7d3")) {                    Plotly.newPlot(                        "4c010246-2609-498b-91e9-3c8666add7d3",                        [{"marker":{"color":"blue"},"name":"R1 Precision","x":["Gemma 2b","Gemma2 9b","Llama 3","Llama 3.1","Mistral FILM"],"y":[0.153977596,0.2213290856,0.12468686039999999,0.1873727637,0.1940948097],"type":"bar"},{"marker":{"color":"green"},"name":"R1 Recall","x":["Gemma 2b","Gemma2 9b","Llama 3","Llama 3.1","Mistral FILM"],"y":[0.1201105487,0.1769496379,0.1350088531,0.1611992496,0.147957477],"type":"bar"},{"marker":{"color":"red"},"name":"R1 F1","x":["Gemma 2b","Gemma2 9b","Llama 3","Llama 3.1","Mistral FILM"],"y":[0.123750049,0.1896771367,0.11864793300000001,0.1640282137,0.1595684142],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{" ...

# %%
import plotly.express as px



fig = px.line(
    combined_dfL, 
    x='Context size', 
    y='R-L Precision', 
    color='Model',  
    markers=True,   
    title='R-L Precision vs Context size for each Model'
)

fig.update_layout(
    xaxis_title='Context size',
    yaxis_title='R-L Precision',
    legend_title='Model'
)

fig.show()
# Out:
# <div>                            <div id="41b166b5-aff7-4d7f-9961-41d859f001bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41b166b5-aff7-4d7f-9961-41d859f001bf")) {                    Plotly.newPlot(                        "41b166b5-aff7-4d7f-9961-41d859f001bf",                        [{"hovertemplate":"Model=Mistral FILM\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L Precision=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mistral FILM","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mistral FILM","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.511438707,0.566932822,0.597046045,0.401227519,0.518908252,0.534515617,0.507263812,0.47862732,0.483694115,0.45202059],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3.1\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L Precision=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3.1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3.1","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.521026817,0.473496871,0.555846452,0.490975791,0.49408927,0.531746938,0.47635566,0.449624572,0.458056396,0.431039402],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma 2b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L Precision=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma 2b","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma 2b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.444542029,0.525488862,0.559460322,0.401413774,0.509192622,0.481307501,0.4450993,0.41910406,0.493197617,0.476945733],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L Precision=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.431332581,0.480321009,0.50848453,0.428135087,0.406187597,0.399412533,0.330831029,0.388562373,0.312235052,0.405195921],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma2 9b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L Precision=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma2 9b","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma2 9b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.608291241,0.482797211,0.544245487,0.502325476,0.498409951,0.476113307,0.534472256,0.490420233,0.480566444,0.512256698],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth" ...

# %%
import plotly.express as px



fig = px.line(
    combined_dfL, 
    x='Context size', 
    y='R-L Recall', 
    color='Model',  
    markers=True,   
    title='R-L Recall vs Context size for each Model'
)

fig.update_layout(
    xaxis_title='Context size',
    yaxis_title='R-L Recall',
    legend_title='Model'
)

fig.show()
# Out:
# <div>                            <div id="ec21965b-8932-4fe5-b8f8-5d93011b81f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec21965b-8932-4fe5-b8f8-5d93011b81f7")) {                    Plotly.newPlot(                        "ec21965b-8932-4fe5-b8f8-5d93011b81f7",                        [{"hovertemplate":"Model=Mistral FILM\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L Recall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mistral FILM","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mistral FILM","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.422754579,0.430980882,0.428679102,0.460814074,0.417694811,0.370648201,0.405729317,0.396773266,0.415088905,0.373853733],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3.1\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L Recall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3.1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3.1","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.427051439,0.470338076,0.452244914,0.463588934,0.484305714,0.382278284,0.392422132,0.382348314,0.426894331,0.432739995],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma 2b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L Recall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma 2b","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma 2b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.427314415,0.369837633,0.380804017,0.43544103,0.34808556,0.355428142,0.363444607,0.385403139,0.422905137,0.384784258],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L Recall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.424029498,0.450286653,0.432193462,0.438583169,0.487387889,0.463097647,0.476144771,0.396183834,0.496134582,0.392023569],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma2 9b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L Recall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma2 9b","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma2 9b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.470904056,0.479931134,0.510972485,0.480256853,0.439247985,0.404994312,0.424123777,0.327927004,0.389282151,0.376574887],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type" ...

# %%
import plotly.express as px


fig = px.line(
    combined_dfL, 
    x='Context size', 
    y='R-L F1', 
    color='Model',  
    markers=True,   
    title='R-L F1 vs Context size for each Model'
)


fig.update_layout(
    xaxis_title='Context size',
    yaxis_title='R-L F1',
    legend_title='Model'
)

fig.show()
# Out:
# <div>                            <div id="72e6f6b3-05a1-4b4e-a1ca-1423e40bfe1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72e6f6b3-05a1-4b4e-a1ca-1423e40bfe1e")) {                    Plotly.newPlot(                        "72e6f6b3-05a1-4b4e-a1ca-1423e40bfe1e",                        [{"hovertemplate":"Model=Mistral FILM\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L F1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mistral FILM","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mistral FILM","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.439404919,0.470534404,0.486807173,0.40833665,0.451155677,0.417786085,0.428186962,0.413956005,0.421237361,0.388137394],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3.1\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L F1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3.1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3.1","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.462715484,0.441707205,0.470284887,0.448698549,0.474573874,0.423224078,0.416310409,0.383464561,0.402247108,0.407020347],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma 2b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L F1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma 2b","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma 2b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.395594149,0.411171962,0.430293337,0.388748842,0.399018428,0.382742678,0.383239315,0.352173627,0.400071519,0.390798007],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Llama 3\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L F1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Llama 3","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Llama 3","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.396149545,0.411028562,0.418872061,0.368535479,0.425011047,0.414916425,0.388148424,0.365039218,0.374996576,0.338859658],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Gemma2 9b\u003cbr\u003eContext size=%{x}\u003cbr\u003eR-L F1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gemma2 9b","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gemma2 9b","orientation":"v","showlegend":true,"x":["442-1060","1060-1670","1670-2280","2280-2900","2900-3510","3510-4130","4130-4740","4740-5350","5350-5920","5920-6580"],"xaxis":"x","y":[0.522947889,0.456822533,0.510532885,0.474339239,0.45475511,0.429611947,0.454671326,0.384532916,0.405006856,0.424425532],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","color ...

# %%
import pandas as pd
import plotly.graph_objects as go

combined_dfL['R-L Precision'] = pd.to_numeric(combined_dfL['R-L Precision'], errors='coerce')
combined_dfL['R-L Recall'] = pd.to_numeric(combined_dfL['R-L Recall'], errors='coerce')
combined_dfL['R-L F1'] = pd.to_numeric(combined_dfL['R-L F1'], errors='coerce')

avg_metricsL = combined_dfL.groupby('Model').agg({
    'R-L Precision': 'mean',
    'R-L Recall': 'mean',
    'R-L F1': 'mean'
}).reset_index()

fig = go.Figure()

fig.add_trace(go.Bar(
    x=avg_metricsL['Model'],
    y=avg_metricsL['R-L Precision'],
    name='R-L Precision',
    marker_color='blue'
))

fig.add_trace(go.Bar(
    x=avg_metricsL['Model'],
    y=avg_metricsL['R-L Recall'],
    name='R-L Recall',
    marker_color='green'
))

fig.add_trace(go.Bar(
    x=avg_metricsL['Model'],
    y=avg_metricsL['R-L F1'],
    name='R-L F1',
    marker_color='red'
))

fig.update_layout(
    title='Comparison of Average R-L Metrics for Each Model',
    xaxis_title='Model',
    yaxis_title='Average Score',
    barmode='group',  
    legend_title='Metrics',
    plot_bgcolor='rgba(0,0,0,0)',  
    xaxis=dict(tickangle=-45)  
)

fig.show()
# Out:
# <div>                            <div id="9fea04b6-97ea-4188-9a95-2c04d31bc567" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fea04b6-97ea-4188-9a95-2c04d31bc567")) {                    Plotly.newPlot(                        "9fea04b6-97ea-4188-9a95-2c04d31bc567",                        [{"marker":{"color":"blue"},"name":"R-L Precision","x":["Gemma 2b","Gemma2 9b","Llama 3","Llama 3.1","Mistral FILM"],"y":[0.47557518199999993,0.5129898304,0.4090697712,0.4882258169,0.5051674799],"type":"bar"},{"marker":{"color":"green"},"name":"R-L Recall","x":["Gemma 2b","Gemma2 9b","Llama 3","Llama 3.1","Mistral FILM"],"y":[0.3873447938,0.4304214644,0.44560650739999996,0.4314212133,0.412301687],"type":"bar"},{"marker":{"color":"red"},"name":"R-L F1","x":["Gemma 2b","Gemma2 9b","Llama 3","Llama 3.1","Mistral FILM"],"y":[0.39338518640000003,0.4517646233,0.3901556995,0.43302465019999997,0.432554263],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a ...
